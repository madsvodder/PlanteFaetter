// %%
%use dataframe
        import java.sql.DriverManager
        import java.util.*

USE {
    dependencies("org.mariadb.jdbc:mariadb-java-client:3.5.7")
}

val URL = "10.176.210.220"
val USER_NAME = "root"
val PASSWORD = "EASV6000"
